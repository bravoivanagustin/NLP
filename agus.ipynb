# %% [markdown]
# # Limpieza datasets de paraphrasing

# %%
import pandas as pd
import numpy as np

# %%
df_1 = pd.read_csv('datasets/paraphrasing/english_task_c.csv')
df_1.head()
# Out:
#                                               text_0  \
# 0           I see that your team played well today!
# 1  Anthony Taylor is such a fair referee, I wish ...
# 2     the weather is gloomy, just raining and dull.
# 3  People going out to get there boosters without...
# 4  Really great weather we're having, love a bit ...
#
#                                               text_1  sarcastic_id_ref  \
# 0     I'm sorry that your team didn't win yesterday.                 0
# 1  I hope Anthony Taylor is never put in charge o...                 0
# 2                     What a glorious weather today                  1
# 3  Nice to see the sheep getting their boosters t...                 1
# 4  Really cold January so far - looking forward t...                 0
#
#    human_aggregated  human_votes
# 0                 0            5
# 1                 0            5
# 2                 1            5
# 3                 1            5
# 4                 0            5

# %%
print("Cantidad de datos: " + str(len(df_1)))
print("Cantidad de ejemplos donde coincide la etiqueta con los votos humanos: " + str(sum(df_1["human_aggregated"] == df_1["sarcastic_id_ref"])))
# Out:
# Cantidad de datos: 200
# Cantidad de ejemplos donde coincide la etiqueta con los votos humanos: 194

# %%
df_2 = pd.read_csv('datasets/paraphrasing/train.En.csv')
df_2.drop(columns=["Unnamed: 0"], inplace=True)
df_2[df_2.columns[3:]] = df_2.iloc[:,3:].fillna(0).astype(int)
df_2.head()
# Out:
#                                                tweet  sarcastic  \
# 0  The only thing I got from college is a caffein...          1
# 1  I love it when professors draw a big question ...          1
# 2  Remember the hundred emails from companies whe...          1
# 3  Today my pop-pop told me I was not “forced” to...          1
# 4  @VolphanCarol @littlewhitty @mysticalmanatee I...          1
#
#                                             rephrase  sarcasm  irony  satire  \
# 0  College is really difficult, expensive, tiring...        0      1       0
# 1  I do not like when professors don’t write out ...        1      0       0
# 2  I, at the bare minimum, wish companies actuall...        0      1       0
# 3  Today my pop-pop told me I was not "forced" to...        1      0       0
# 4  I would say Ted Cruz is an asshole and doesn’t...        1      0       0
#
#    understatement  overstatement  rhetorical_question
# 0               0              0                    0
# 1               0              0                    0
# 2               0              0                    0
# 3               0              0                    0
# 4               0              0                    0

# %%
print("Cantidad de datos: " + str(len(df_2)))
print("Cantidad de datos sarcasticos: " + str(sum(df_2["sarcastic"] == 1)))
# Out:
# Cantidad de datos: 3468
# Cantidad de datos sarcasticos: 867

# %% [markdown]
# Medio pelo... Veamos que podemos hacer con esto

# %% [markdown]
# Una idea a discutir: podriamos hacer que aprenda en parte a reconocer sarcasmo (o distintos tipos de este) para que despues pueda reproducirlo. Si usamos esto en la primera parte de training y despues lo bombardeamos con muchisimos datos con estructura de chat?

# %% [markdown]
# Formato a llevar:
#
# - text: el texto sarcástico
# - is_sarcastic: booleano
# - degree_of_sarcasm: un entero del 0 al 10 (puede ser nulo)
# - paraphrase: el texto parafraseado sin sarcasmo si es que corresponde
# - context: el contexto del que proviene si es que es una respuesta a un hilo
# - type: one of "sarcasm", "satire", "rhetorical question", etc
# - source: la fuente, de que dataset proviene
# - task: la tarea para la cual se va a usar

# %%
def procesar_fila_dataframe_1(row):
    if row['sarcastic_id_ref'] == 0:
        texto_sarcastico = row['text_0']
        paraphrase = row['text_1']
    else:
        texto_sarcastico = row['text_1']
        paraphrase = row['text_0']    
        
    return {
        'text': texto_sarcastico,
        'is_sarcastic': 1,
        'deegree_of_sarcasm': None,
        'paraphrase': paraphrase,
        'context': None,
        'type': None,
        'source': 'paraphrasing/english_task_c',
        'task': 'paraphrasing'
    }

# %%
prueba = df_1.apply(procesar_fila_dataframe_1, axis=1)
df_procesado_1 = pd.DataFrame(prueba.tolist())

# %%
df_procesado_1
# Out:
#                                                   text  is_sarcastic  \
# 0             I see that your team played well today!              1
# 1    Anthony Taylor is such a fair referee, I wish ...             1
# 2                       What a glorious weather today              1
# 3    Nice to see the sheep getting their boosters t...             1
# 4    Really great weather we're having, love a bit ...             1
# ..                                                 ...           ...
# 195   the tories betrayed the nation, what a surprise!             1
# 196  Cant wait to spend the rest of my life waiting...             1
# 197  Isn't it just amazing how competent the govern...             1
# 198  Thanks Boris Johnson for restricting travel ab...             1
# 199  Where is my invite to the tories Christmas par...             1
#
#     deegree_of_sarcasm                                         paraphrase  \
# 0                 None     I'm sorry that your team didn't win yesterday.
# 1                 None  I hope Anthony Taylor is never put in charge o...
# 2                 None     the weather is gloomy, just raining and dull.
# 3                 None  People going out to get there boosters without...
# 4                 None  Really cold January so far - looking forward t...
# ..                 ...                                                ...
# 195               None        the tories betrayed the nation, as expected
# 196               None  Cant believe we have to spend the rest of our ...
# 197               None  Everything is a total mess, how can anyone be ...
# 198               None  The reasoning behind the tightening of travel ...
# 199               None  The Tory Christmas party scandal is a shame to...
#
#     context  type                       source          task
# 0      None  None  paraphrasing/english_task_c  paraphrasing
# 1      None  None  paraphrasing/english_task_c  paraphrasing
# 2      None  None  paraphrasing/english_task_c  paraphrasing
# 3      None  None  paraphrasing/english_task_c  paraphrasing
# 4      None  None  paraphrasing/english_task_c  paraphrasing
# ..      ...   ...                          ...           ...
# 195    None  None  paraphrasing/english_task_c  paraphrasing
# 196    None  None  paraphrasing/english_task_c  paraphrasing
# 197    None  None  paraphrasing/english_task_c  paraphrasing
# 198    None  None  paraphrasing/english_task_c  paraphrasing
# 199    None  None  paraphrasing/english_task_c  paraphrasing
#
# [200 rows x 8 columns]

# %%
def procesar_fila_dataframe_2(row):
    
    type = (np.array(df_2.columns[3:]) * np.array(row[3:])).sum()

    return {
        'text': row['tweet'],
        'is_sarcastic': row['sarcastic'],
        'deegree_of_sarcasm': None,
        'paraphrase': row['rephrase'] if row['sarcastic'] == 1 else None,
        'context': None,
        'type': type if type != "" else None,
        'source': 'paraphrasing/train.En',
        'task': 'paraphrasing'
    }

# %%
prueba_2 = df_2.apply(procesar_fila_dataframe_2, axis=1)
df_procesado_2 = pd.DataFrame(prueba_2.tolist())

# %%
df_procesado_2
# Out:
#                                                    text  is_sarcastic  \
# 0     The only thing I got from college is a caffein...             1
# 1     I love it when professors draw a big question ...             1
# 2     Remember the hundred emails from companies whe...             1
# 3     Today my pop-pop told me I was not “forced” to...             1
# 4     @VolphanCarol @littlewhitty @mysticalmanatee I...             1
# ...                                                 ...           ...
# 3463  The population spike in Chicago in 9 months is...             0
# 3464  You'd think in the second to last English clas...             0
# 3465  I’m finally surfacing after a holiday to Scotl...             0
# 3466  Couldn't be prouder today. Well done to every ...             0
# 3467  Overheard as my 13 year old games with a frien...             0
#
#      deegree_of_sarcasm                                         paraphrase  \
# 0                  None  College is really difficult, expensive, tiring...
# 1                  None  I do not like when professors don’t write out ...
# 2                  None  I, at the bare minimum, wish companies actuall...
# 3                  None  Today my pop-pop told me I was not "forced" to...
# 4                  None  I would say Ted Cruz is an asshole and doesn’t...
# ...                 ...                                                ...
# 3463               None                                               None
# 3464               None                                               None
# 3465               None                                               None
# 3466               None                                               None
# 3467               None                                               None
#
#      context     type                 source          task
# 0       None    irony  paraphrasing/train.En  paraphrasing
# 1       None  sarcasm  paraphrasing/train.En  paraphrasing
# 2       None    irony  paraphrasing/train.En  paraphrasing
# 3       None  sarcasm  paraphrasing/train.En  paraphrasing
# 4       None  sarcasm  paraphrasing/train.En  paraphrasing
# ...      ...      ...                    ...           ...
# 3463    None     None  paraphrasing/train.En  paraphrasing
# 3464    None     None  paraphrasing/train.En  paraphrasing
# 3465    None     None  paraphrasing/train.En  paraphrasing
# 3466    None     None  paraphrasing/train.En  paraphrasing
# 3467    None     None  paraphrasing/train.En  paraphrasing
#
# [3468 rows x 8 columns]

# %%
df_union = pd.concat([df_procesado_1, df_procesado_2], ignore_index=True)
df_union
# Out:
#                                                    text  is_sarcastic  \
# 0              I see that your team played well today!              1
# 1     Anthony Taylor is such a fair referee, I wish ...             1
# 2                        What a glorious weather today              1
# 3     Nice to see the sheep getting their boosters t...             1
# 4     Really great weather we're having, love a bit ...             1
# ...                                                 ...           ...
# 3663  The population spike in Chicago in 9 months is...             0
# 3664  You'd think in the second to last English clas...             0
# 3665  I’m finally surfacing after a holiday to Scotl...             0
# 3666  Couldn't be prouder today. Well done to every ...             0
# 3667  Overheard as my 13 year old games with a frien...             0
#
#      deegree_of_sarcasm                                         paraphrase  \
# 0                  None     I'm sorry that your team didn't win yesterday.
# 1                  None  I hope Anthony Taylor is never put in charge o...
# 2                  None     the weather is gloomy, just raining and dull.
# 3                  None  People going out to get there boosters without...
# 4                  None  Really cold January so far - looking forward t...
# ...                 ...                                                ...
# 3663               None                                               None
# 3664               None                                               None
# 3665               None                                               None
# 3666               None                                               None
# 3667               None                                               None
#
#      context  type                       source          task
# 0       None  None  paraphrasing/english_task_c  paraphrasing
# 1       None  None  paraphrasing/english_task_c  paraphrasing
# 2       None  None  paraphrasing/english_task_c  paraphrasing
# 3       None  None  paraphrasing/english_task_c  paraphrasing
# 4       None  None  paraphrasing/english_task_c  paraphrasing
# ...      ...   ...                          ...           ...
# 3663    None  None        paraphrasing/train.En  paraphrasing
# 3664    None  None        paraphrasing/train.En  paraphrasing
# 3665    None  None        paraphrasing/train.En  paraphrasing
# 3666    None  None        paraphrasing/train.En  paraphrasing
# 3667    None  None        paraphrasing/train.En  paraphrasing
#
# [3668 rows x 8 columns]

# %% [markdown]
# Yo creo que va a servir bastante, falta ver si pongo etiquetas de usuario y asistente o como planteo la entrada.
